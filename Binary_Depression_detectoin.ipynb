# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d5df0069828e> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     258       with _output.use_tags('dfs-auth-dance'):
#     259         with open(fifo, 'w') as fifo_file:
# --> 260           fifo_file.write(get_code(auth_prompt) + '\n')
#     261       wrote_to_fifo = True
#     262     elif case == 5:
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
import pandas as pd
import torch
import torch.nn as nn
import numpy as np
from collections import Counter
from torch.nn.utils.rnn import pack_padded_sequence
from torchsummary import summary
# !wget http://nlp.stanford.edu/data/glove.42B.300d.zip
# !unzip '/content/glove.42B.300d.zip'

# %%
TRAIN_PATH = '/content/drive/MyDrive/Depression-Detection/new-train-split.csv'
TEST_PATH = '/content/drive/MyDrive/Depression-Detection/new-test-split.csv'
VAL_PATH = '/content/drive/MyDrive/Depression-Detection/new-dev-split.csv'
DEVICE = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
EMBEDDING_FILE = '/content/glove.42B.300d.txt'
vocab2index = {"":0, "UNK":1}
MAX_LEN = 2204
MIN_LEN = 109

# %%
def get_data(dataset):
  """
  returns features and their labels
  """
  features = dataset.Text
  PHQ = dataset.PHQ8_Binary
  # PTSD = dataset.PTSD
  PTSD = dataset['PCL-C']
  PTSD = np.where(PTSD == "yes", 1, 0)
  
  return features, PHQ, PTSD

# %%
def get_embeddings():
    embeddings_index = {}
    with open(EMBEDDING_FILE, encoding='utf8') as f:
        for line in f:
            values = line.rstrip().rsplit(' ')
            word = values[0]
            coefs = np.asarray(values[1:], dtype='float32')
            embeddings_index[word] = coefs
    return embeddings_index

# %%
def tokenize_text(text):
  tokens = []
  for txt in text:
    tokens.append(txt.split())
  return tokens

# %%
def encode_sentence(text, vocab2index):
    tokenized = tokenize_text([text])
    encoded = np.zeros(MAX_LEN, dtype=np.float32)
    enc1 = np.array([vocab2index.get(word, vocab2index["UNK"]) for word in tokenized[0]])
    length = min(MAX_LEN, len(enc1))
    encoded[:length] = enc1[:length]
    return  encoded, length

# %%
def get_emb_matrix(glove_embed, word_counts, emb_size = 300):
    """
    returns weight matrix for embeddings
    :params: glove_embed - glove dictionary
             word_counts - unique words in dataset
    """

    vocab_size = len(word_counts) + 2 
    vocab_to_idx = {}
    vocab = ["", "UNK"]
    W = np.zeros((vocab_size, emb_size), dtype="float32")
    W[0] = np.zeros(emb_size, dtype='float32') # adding a vector for padding
    W[1] = np.random.uniform(-0.25, 0.25, emb_size) # adding a vector for unknown words 
    vocab_to_idx["UNK"] = 1
    i = 2
    for word in word_counts:
        if word in glove_embed:
            W[i] = glove_embed[word]
        else:
            W[i] = np.random.uniform(-0.25,0.25, emb_size)
        vocab_to_idx[word] = i
        vocab.append(word)
        i += 1   
    return W, np.array(vocab), vocab_to_idx

# %%
class EarlyStopping:
    """
    Early stops the training if validation loss doesn't improve after a given patience.
    
    """
    def __init__(self, patience=8, verbose=False, delta=0, path= '/content/early_stopping_model.pth'):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 10
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'early_stopping_vgg16model.pth'   
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
    
    def __call__(self, val_loss, model):
        
        score = -val_loss
        
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            
        elif score < self.best_score + self.delta:
            self.counter += 1
            
            if self.counter >= self.patience:
                self.early_stop = True
                
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0   
    
    def save_checkpoint(self, val_loss, model):
        """
        saves the current best version of the model if there is decrease in validation loss
        """
        torch.save(model.state_dict(), self.path)
        self.vall_loss_min = val_loss

# %%
class DepressionDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, PHQ, PTSD):
        self.encodings = encodings
        self.PHQ = PHQ
        self.PTSD = PTSD

    def __getitem__(self, idx):
        encoding = torch.tensor(self.encodings[idx][0])
        phq_score = torch.tensor(self.PHQ[idx])
        ptsd_score = torch.tensor(self.PTSD[idx])
        length = self.encodings[idx][1]
        
        return encoding, length, phq_score, ptsd_score

    def __len__(self):
        return len(self.PHQ)

# %%
class LSTM(torch.nn.Module) :
    def __init__(self, vocab_size, embedding_dim, hidden_dim, glove_weights) :
        super().__init__()

        self.dropout = nn.Dropout(0.4)
        self.embeddings = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.embeddings.weight.data.copy_(torch.from_numpy(glove_weights))
        self.embeddings.weight.requires_grad = False
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True, num_layers=1, bidirectional=False)


        self.MLP = nn.Sequential(
            nn.Linear(hidden_dim,128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.4)
        )

        self.ptsd_head = nn.Sequential(
            nn.Linear(128, 128),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(),
            nn.Linear(128,1)
        )

        self.phq_head = nn.Sequential(
            nn.Linear(128, 1),    
        )

        
    def forward(self, sentence, sentence_length):
        sentence_embed = self.embeddings(sentence)
        sentence_embed = self.dropout(sentence_embed)

        sentence_pack = pack_padded_sequence(sentence_embed, sentence_length, batch_first=True, enforce_sorted=False)
        out_pack, (ht, ct) = self.lstm(sentence_pack)
        features = self.MLP(ht[-1])
        ptsd = self.ptsd_head(features)
        phq = self.phq_head(features)

        return torch.squeeze(phq, 1), torch.squeeze(ptsd, 1)

# %%
def get_weights(train_val_df):
    
    neg, pos = np.bincount(train_val_df)
    print(" 0 : ",neg)
    print(" 1 : ",pos)
    
    pos_weight = torch.FloatTensor([neg/pos])
    return pos_weight

# %%
#read data from csvs
train_dataset = pd.read_csv(TRAIN_PATH)
test_dataset = pd.read_csv(TEST_PATH)
val_dataset = pd.read_csv(VAL_PATH) 

# generate sentences and their labels
X_train, train_PHQ, train_PTSD = get_data(train_dataset)
X_val, val_PHQ, val_PTSD = get_data(val_dataset)
X_test, test_PHQ, test_PTSD = get_data(test_dataset)

print("Weights for PTSD : ")
train_val = np.append(train_PTSD, val_PTSD)
pos_weight_ptsd = get_weights(train_val)

print("Weights for PHQ : ")
train_val_phq = np.append(train_PHQ, val_PHQ)
pos_weight_phq = get_weights(train_val_phq)

# embeddings_dict = get_embeddings()

train_text = list(X_train.values)
val_text = list(X_val.values)
test_text = list(X_test.values)
train_tokens = tokenize_text(train_text)
val_tokens = tokenize_text(val_text)
test_tokens = tokenize_text(test_text)

counts = Counter()
for tok in train_tokens:
  counts.update(tok)
for tok in val_tokens:
  counts.update(tok)
for tok in test_tokens:  
  counts.update(tok)

print("Length of unique words before removing frequent words: ", len(counts))
for words in list(counts):
  if counts[words] > 3000:
    del counts[words]
print("Length of unique words after removing frequent words: ", len(counts))

#creating vocabulary

words = ["", "UNK"]
for word in counts:
    vocab2index[word] = len(words)
    words.append(word)

train_encoded = []
val_encoded = []
test_encoded = []

for text in train_text:
  train_encoded.append(encode_sentence(text, vocab2index))
for text in val_text:
  val_encoded.append(encode_sentence(text, vocab2index))
for text in test_text:
  test_encoded.append(encode_sentence(text, vocab2index))

embed_matrix, vocab, vocab_to_idx = get_emb_matrix(embeddings_dict, counts)
print("Shape of Embedding matrix : ", embed_matrix.shape)
print("Shape of Vocabulary : ", vocab.shape)
print("Length of Vocab to index : ", len(vocab_to_idx))
# Out:
# Weights for PTSD :
#  0 :  101
#  1 :  41
# Weights for PHQ :
#  0 :  100
#  1 :  42
# Length of unique words before removing frequent words:  8358
# Length of unique words after removing frequent words:  8351
# Shape of Embedding matrix :  (8353, 300)
# Shape of Vocabulary :  (8353,)
# Length of Vocab to index :  8352

# %%
vocab_size = 8353
embedding_dim = 300
hidden_dim = 256
lr = 1e-5
epochs = 500
batch_size = 16

model = LSTM(vocab_size, embedding_dim, hidden_dim, embed_matrix)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
criterion_phq = torch.nn.BCEWithLogitsLoss(pos_weight=pos_weight_phq).to(DEVICE) 
criterion_ptsd = torch.nn.BCEWithLogitsLoss(pos_weight=pos_weight_ptsd).to(DEVICE) 

train_loader = torch.utils.data.DataLoader(DepressionDataset(train_encoded, train_PHQ, train_PTSD), batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(DepressionDataset(val_encoded, val_PHQ, val_PTSD), batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(DepressionDataset(test_encoded, test_PHQ, test_PTSD), batch_size=batch_size, shuffle=True)

# %%
def train(model, optimizer, criterion_phq, criterion_ptsd, train_loader, val_loader, epochs):

  epoch_train_phq_loss = []
  epoch_train_ptsd_loss = []
  epoch_train_total_loss = []
  epoch_train_ptsd_acc = []
  epoch_train_phq_acc = []

  epoch_val_phq_loss = []
  epoch_val_ptsd_loss = []
  epoch_val_total_loss = []
  epoch_val_ptsd_acc = []
  epoch_val_phq_acc = []


  losses = {'train':{'total':[], 'phq':[], 'ptsd':[]}, 'val':{'total':[], 'phq':[], 'ptsd':[]}}
  accuracy = {'train':{'phq':[], 'ptsd':[]}, 'val':{'phq':[], 'ptsd':[]}}

  print("Training started...\n")
  model.to(DEVICE)
  scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=60, gamma=0.1, last_epoch=-1, verbose=True)
  early_stop = EarlyStopping(patience=12)

  for epoch in range(epochs):
    total_phq, correct_phq, total_ptsd, correct_ptsd = 0, 0, 0, 0
    print("Epoch : ", epoch+1)
    model.train()
    for sentence, length, phq_score, ptsd_score in train_loader:
      sentence = sentence.to(DEVICE).long()
      phq_score = phq_score.to(DEVICE).type(torch.float32)
      ptsd_score = ptsd_score.to(DEVICE).type(torch.float32)

      optimizer.zero_grad()

      phq_op, ptsd_op = model(sentence, length)

      loss_phq = criterion_phq(phq_op, phq_score)
      loss_ptsd = criterion_ptsd(ptsd_op, ptsd_score)
      loss = loss_phq + loss_ptsd
      loss.backward()

      phq_op = torch.sigmoid(phq_op)
      ptsd_op = torch.sigmoid(ptsd_op)
 
 
      predicted_phq = torch.round(phq_op).squeeze(-1) 
      total_phq += phq_score.size(0)
      correct_phq += (predicted_phq==phq_score).sum().item()

      predicted_ptsd = torch.round(ptsd_op).squeeze(-1) 
      total_ptsd += ptsd_score.size(0)
      correct_ptsd += (predicted_ptsd==ptsd_score).sum().item()
  
      epoch_train_phq_loss.append(loss_phq.item())
      epoch_train_ptsd_loss.append(loss_ptsd.item())
      epoch_train_total_loss.append(loss.item())

      optimizer.step()
      
    train_total_loss = np.average(epoch_train_total_loss)
    train_phq_loss = np.average(epoch_train_phq_loss)
    train_ptsd_loss = np.average(epoch_train_ptsd_loss)
    train_phq_acc = correct_phq/total_phq
    train_ptsd_acc = correct_ptsd/total_ptsd
  
    total_phq, correct_phq, total_ptsd, correct_ptsd = 0, 0, 0, 0
    model.eval()
    with torch.no_grad():
      for sentence, length, phq_score, ptsd_score in val_loader:
        sentence = sentence.to(DEVICE).long()
        phq_score = phq_score.to(DEVICE).type(torch.float32)
        ptsd_score = ptsd_score.to(DEVICE).type(torch.float32)

        phq_op, ptsd_op = model(sentence,length)
        
        loss_phq = criterion_phq(phq_op, phq_score)
        loss_ptsd = criterion_ptsd(ptsd_op, ptsd_score)
        loss = loss_phq + loss_ptsd

        phq_op = torch.sigmoid(phq_op)
        ptsd_op = torch.sigmoid(ptsd_op)

        predicted_phq = torch.round(phq_op).squeeze(-1) 
        total_phq += phq_score.size(0)
        correct_phq += (predicted_phq==phq_score).sum().item()

        predicted_ptsd = torch.round(ptsd_op).squeeze(-1) 
        total_ptsd += ptsd_score.size(0)
        correct_ptsd += (predicted_ptsd==ptsd_score).sum().item()

        epoch_val_phq_loss.append(loss_phq.item())
        epoch_val_ptsd_loss.append(loss_ptsd.item())
        epoch_val_total_loss.append(loss.item())

      
      val_total_loss = np.average(epoch_val_total_loss)
      val_phq_loss = np.average(epoch_val_phq_loss)
      val_ptsd_loss = np.average(epoch_val_ptsd_loss)
      val_phq_acc = correct_phq/total_phq
      val_ptsd_acc = correct_ptsd/total_ptsd

    scheduler.step()
    early_stop(val_total_loss, model)

    if early_stop.early_stop:
          print("Early stopping")
          used_early_stopping  = True
          break

    print("Train total loss: {0:.3f}, Train PHQ loss: {1:.3f}, Train PTSD loss: {2:.3f} ".format(train_total_loss, train_phq_loss, train_ptsd_loss))
    print("Val total loss: {0:.3f}, Val PHQ loss: {1:.3f}, Val PTSD loss: {2:.3f} ".format(val_total_loss, val_phq_loss, val_ptsd_loss))
    print("Train PHQ accuracy: {0:.3f} Val PHQ accuracy: {1:.3f} Train PTSD accuracy: {2:.3f} Val PTSD accuracy: {3:.3f}".format(train_phq_acc, val_phq_acc, train_ptsd_acc, val_ptsd_acc))
    print('--------------------------------------------------------------------------------------------------------------------')

    losses['train']['total'].append(train_total_loss) 
    losses['train']['phq'].append(train_phq_loss) 
    losses['train']['ptsd'].append(train_ptsd_loss) 

    losses['val']['total'].append(val_total_loss) 
    losses['val']['phq'].append(val_phq_loss) 
    losses['val']['ptsd'].append(val_ptsd_loss) 
    
    accuracy['train']['phq'].append(train_phq_acc) 
    accuracy['train']['ptsd'].append(train_ptsd_acc) 

    accuracy['val']['phq'].append(val_phq_acc) 
    accuracy['val']['ptsd'].append(val_ptsd_acc) 
  

  return model, losses, accuracy

# %%
model, losses, accuracy = train(model, optimizer, criterion_phq, criterion_ptsd, train_loader, val_loader, epochs)
# Out:
# Training started...
#
# Adjusting learning rate of group 0 to 1.0000e-05.
# Epoch :  1
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 1.995, Train PHQ loss: 0.960, Train PTSD loss: 1.035
# Val total loss: 2.013, Val PHQ loss: 1.019, Val PTSD loss: 0.994
# Train PHQ accuracy: 0.570 Val PHQ accuracy: 0.600 Train PTSD accuracy: 0.682 Val PTSD accuracy: 0.286
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  2
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.013, Train PHQ loss: 0.970, Train PTSD loss: 1.044
# Val total loss: 2.012, Val PHQ loss: 1.018, Val PTSD loss: 0.994
# Train PHQ accuracy: 0.542 Val PHQ accuracy: 0.543 Train PTSD accuracy: 0.682 Val PTSD accuracy: 0.286
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  3
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.010, Train PHQ loss: 0.967, Train PTSD loss: 1.043
# Val total loss: 1.958, Val PHQ loss: 0.990, Val PTSD loss: 0.968
# Train PHQ accuracy: 0.579 Val PHQ accuracy: 0.543 Train PTSD accuracy: 0.645 Val PTSD accuracy: 0.286
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  4
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.018, Train PHQ loss: 0.977, Train PTSD loss: 1.041
# Val total loss: 1.951, Val PHQ loss: 0.998, Val PTSD loss: 0.953
# Train PHQ accuracy: 0.551 Val PHQ accuracy: 0.571 Train PTSD accuracy: 0.701 Val PTSD accuracy: 0.286
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  5
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.005, Train PHQ loss: 0.976, Train PTSD loss: 1.029
# Val total loss: 1.946, Val PHQ loss: 1.002, Val PTSD loss: 0.943
# Train PHQ accuracy: 0.579 Val PHQ accuracy: 0.657 Train PTSD accuracy: 0.682 Val PTSD accuracy: 0.286
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  6
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.006, Train PHQ loss: 0.984, Train PTSD loss: 1.022
# Val total loss: 1.955, Val PHQ loss: 1.004, Val PTSD loss: 0.951
# Train PHQ accuracy: 0.589 Val PHQ accuracy: 0.629 Train PTSD accuracy: 0.645 Val PTSD accuracy: 0.314
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  7
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.010, Train PHQ loss: 0.983, Train PTSD loss: 1.027
# Val total loss: 1.937, Val PHQ loss: 0.992, Val PTSD loss: 0.945
# Train PHQ accuracy: 0.561 Val PHQ accuracy: 0.629 Train PTSD accuracy: 0.682 Val PTSD accuracy: 0.457
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  8
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.002, Train PHQ loss: 0.977, Train PTSD loss: 1.025
# Val total loss: 1.922, Val PHQ loss: 0.983, Val PTSD loss: 0.939
# Train PHQ accuracy: 0.589 Val PHQ accuracy: 0.657 Train PTSD accuracy: 0.654 Val PTSD accuracy: 0.514
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  9
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.010, Train PHQ loss: 0.982, Train PTSD loss: 1.027
# Val total loss: 1.910, Val PHQ loss: 0.977, Val PTSD loss: 0.932
# Train PHQ accuracy: 0.495 Val PHQ accuracy: 0.657 Train PTSD accuracy: 0.673 Val PTSD accuracy: 0.514
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  10
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.016, Train PHQ loss: 0.985, Train PTSD loss: 1.031
# Val total loss: 1.930, Val PHQ loss: 0.986, Val PTSD loss: 0.944
# Train PHQ accuracy: 0.495 Val PHQ accuracy: 0.657 Train PTSD accuracy: 0.664 Val PTSD accuracy: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  11
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.018, Train PHQ loss: 0.986, Train PTSD loss: 1.032
# Val total loss: 1.918, Val PHQ loss: 0.980, Val PTSD loss: 0.938
# Train PHQ accuracy: 0.570 Val PHQ accuracy: 0.657 Train PTSD accuracy: 0.636 Val PTSD accuracy: 0.571
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  12
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.015, Train PHQ loss: 0.982, Train PTSD loss: 1.033
# Val total loss: 1.923, Val PHQ loss: 0.982, Val PTSD loss: 0.941
# Train PHQ accuracy: 0.626 Val PHQ accuracy: 0.657 Train PTSD accuracy: 0.682 Val PTSD accuracy: 0.543
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  13
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.016, Train PHQ loss: 0.981, Train PTSD loss: 1.034
# Val total loss: 1.915, Val PHQ loss: 0.980, Val PTSD loss: 0.936
# Train PHQ accuracy: 0.607 Val PHQ accuracy: 0.686 Train PTSD accuracy: 0.654 Val PTSD accuracy: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  14
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.015, Train PHQ loss: 0.981, Train PTSD loss: 1.033
# Val total loss: 1.924, Val PHQ loss: 0.982, Val PTSD loss: 0.942
# Train PHQ accuracy: 0.626 Val PHQ accuracy: 0.686 Train PTSD accuracy: 0.682 Val PTSD accuracy: 0.600
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  15
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.014, Train PHQ loss: 0.981, Train PTSD loss: 1.033
# Val total loss: 1.937, Val PHQ loss: 0.995, Val PTSD loss: 0.942
# Train PHQ accuracy: 0.598 Val PHQ accuracy: 0.657 Train PTSD accuracy: 0.673 Val PTSD accuracy: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  16
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.016, Train PHQ loss: 0.982, Train PTSD loss: 1.034
# Val total loss: 1.939, Val PHQ loss: 0.997, Val PTSD loss: 0.942
# Train PHQ accuracy: 0.495 Val PHQ accuracy: 0.686 Train PTSD accuracy: 0.664 Val PTSD accuracy: 0.543
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  17
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.015, Train PHQ loss: 0.981, Train PTSD loss: 1.035
# Val total loss: 1.939, Val PHQ loss: 1.001, Val PTSD loss: 0.938
# Train PHQ accuracy: 0.607 Val PHQ accuracy: 0.657 Train PTSD accuracy: 0.682 Val PTSD accuracy: 0.600
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  18
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.014, Train PHQ loss: 0.981, Train PTSD loss: 1.033
# Val total loss: 1.940, Val PHQ loss: 1.002, Val PTSD loss: 0.939
# Train PHQ accuracy: 0.579 Val PHQ accuracy: 0.686 Train PTSD accuracy: 0.664 Val PTSD accuracy: 0.600
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  19
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.012, Train PHQ loss: 0.980, Train PTSD loss: 1.032
# Val total loss: 1.933, Val PHQ loss: 0.998, Val PTSD loss: 0.935
# Train PHQ accuracy: 0.579 Val PHQ accuracy: 0.686 Train PTSD accuracy: 0.682 Val PTSD accuracy: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  20
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train total loss: 2.011, Train PHQ loss: 0.978, Train PTSD loss: 1.032
# Val total loss: 1.943, Val PHQ loss: 1.003, Val PTSD loss: 0.940
# Train PHQ accuracy: 0.542 Val PHQ accuracy: 0.686 Train PTSD accuracy: 0.673 Val PTSD accuracy: 0.571
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  21
# Adjusting learning rate of group 0 to 1.0000e-05.
# Early stopping

# %%
# torch.save(model,'/content/drive/MyDrive/Depression-Detection/multitask_model.pth')
# f = open('/content/drive/MyDrive/Depression-Detection/model_settings.txt','w+')
# f.write('learning_rate :'+str(lr))
# f.write('hidden dim : '+str(hidden_dim))
# f.write('Model :\n'+str(model))
# f.write('train loss dict : '+str(losses))
# f.close()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def draw_training_curves(train_losses, test_losses, curve_name, epoch):
    plt.clf()
    
    plt.xlim([0,epoch])
    plt.plot(train_losses, label='Training {}'.format(curve_name))
    plt.plot(test_losses, label='Testing {}'.format(curve_name))
    plt.ylabel(curve_name)
    plt.xlabel('Epoch')
    
    plt.title("Depression loss curve")
    plt.legend(frameon=False)
    plt.show()

draw_training_curves(losses['train']['total'],losses['val']['total'], 'total_loss', 47 )

# %%
draw_training_curves(losses['train']['ptsd'],losses['val']['ptsd'], 'PTSD', 47 )

# %%
draw_training_curves(losses['train']['phq'],losses['val']['phq'], 'PHQ', 40 )

# %%
class LSTM_Single_Task(torch.nn.Module) :
    def __init__(self, vocab_size, embedding_dim, hidden_dim, glove_weights) :
        super().__init__()

        self.dropout = nn.Dropout(0.3)
        self.embeddings = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.embeddings.weight.data.copy_(torch.from_numpy(glove_weights))
        self.embeddings.weight.requires_grad = False
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers=2, bidirectional = True, batch_first=True)

        self.MLP = nn.Sequential(
            nn.Linear(hidden_dim,128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Linear(128,1)
        )

    def forward(self, sentence, sentence_length):
        sentence_embed = self.embeddings(sentence)
        sentence_embed = self.dropout(sentence_embed)

        sentence_pack = pack_padded_sequence(sentence_embed, sentence_length, batch_first=True, enforce_sorted=False)
        out_pack, (ht, ct) = self.lstm(sentence_pack)
        task_op = self.MLP(ht[-1])
  
        return torch.squeeze(task_op, 1)

# %%
def train_single_task(task, model, optimizer, criterion, train_loader, val_loader, epochs):

  epoch_train_loss = []
  epoch_val_loss = []
  losses = {'train':[], 'val':[]}
  accuracy = {'train':[], 'val':[]}

  print("Training started...\n")

  model.to(DEVICE)
  scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=60, gamma=0.1, last_epoch=-1, verbose=True)
  early_stop = EarlyStopping(patience=12)
  

  for epoch in range(epochs):

    total = 0
    correct =  0
    print("Epoch : ", epoch+1)
    model.train()
    for sentence, length, phq_score, ptsd_score in train_loader:
      sentence = sentence.to(DEVICE).long()
      phq_score = phq_score.to(DEVICE).type(torch.float32)
      ptsd_score = ptsd_score.to(DEVICE).type(torch.float32)
      if task == 'PHQ':
        label = phq_score
      else:
        label = ptsd_score

      optimizer.zero_grad()

      task_op = model(sentence, length)

      loss = criterion(task_op, label)
      loss.backward()

      task_op = torch.sigmoid(task_op)

      predicted= torch.round(task_op).squeeze(-1) 
      total += label.size(0)
      correct += (predicted==label).sum().item()
   
      epoch_train_loss.append(loss.item())
      optimizer.step()
      
    train_loss = np.average(epoch_train_loss)
    train_accuracy = correct/total

    model.eval()
    total = 0
    correct =  0
    with torch.no_grad():
      for sentence, length, phq_score, ptsd_score in val_loader:
        sentence = sentence.to(DEVICE).long()
        phq_score = phq_score.to(DEVICE).type(torch.float32)
        ptsd_score = ptsd_score.to(DEVICE).type(torch.float32)
        if task == 'PHQ':
          label = phq_score
        else: 
          label = ptsd_score
        
        task_op = model(sentence, length)

        loss = criterion(task_op, label)

        task_op = torch.sigmoid(task_op)

        predicted = torch.round(task_op)
  
        total += label.size(0)
        correct += (predicted==label).sum().item()
        epoch_val_loss.append(loss.item())

    val_loss = np.average(epoch_val_loss)
    val_accuracy = correct/total
    scheduler.step()
    early_stop(val_loss, model)
    

    print("Train loss: {0:.3f} Val loss: {1:.3f}".format(train_loss, val_loss))
    print("Train acc: {0:.3f} Val acc: {1:.3f}".format(train_accuracy, val_accuracy))
    print('--------------------------------------------------------------------------------------------------------------------')

    if early_stop.early_stop:
          print("Early stopping")
          used_early_stopping  = True
          break

    losses['train'].append(train_loss) 
    losses['val'].append(val_loss) 

    accuracy['train'].append(train_accuracy) 
    accuracy['val'].append(val_accuracy) 

  return model, losses, accuracy

# %%
vocab_size = 8353
embedding_dim = 300
hidden_dim = 512
lr = 1e-5
epochs = 500
batch_size = 16

model_task = LSTM_Single_Task(vocab_size, embedding_dim, hidden_dim, embed_matrix)
optimizer = torch.optim.Adam(model_task.parameters(), lr=lr)
criterion = torch.nn.BCEWithLogitsLoss(pos_weight=pos_weight_phq).to(DEVICE) 

train_loader = torch.utils.data.DataLoader(DepressionDataset(train_encoded, train_PHQ, train_PTSD), batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(DepressionDataset(val_encoded, val_PHQ, val_PTSD), batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(DepressionDataset(test_encoded, test_PHQ, test_PTSD), batch_size=batch_size, shuffle=True)

model_task, losses, accuracy = train_single_task('PHQ', model_task, optimizer, criterion, train_loader, val_loader, epochs)
# Out:
# Training started...
#
# Adjusting learning rate of group 0 to 1.0000e-05.
# Epoch :  1
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.976 Val loss: 1.106
# Train acc: 0.523 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  2
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.969 Val loss: 1.022
# Train acc: 0.514 Val acc: 0.343
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  3
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.978 Val loss: 1.018
# Train acc: 0.449 Val acc: 0.343
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  4
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.966 Val loss: 1.032
# Train acc: 0.579 Val acc: 0.343
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  5
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.959 Val loss: 1.028
# Train acc: 0.579 Val acc: 0.343
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  6
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.956 Val loss: 1.013
# Train acc: 0.523 Val acc: 0.343
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  7
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.959 Val loss: 1.020
# Train acc: 0.542 Val acc: 0.343
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  8
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.951 Val loss: 1.017
# Train acc: 0.579 Val acc: 0.314
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  9
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.946 Val loss: 1.023
# Train acc: 0.551 Val acc: 0.343
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  10
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.944 Val loss: 1.024
# Train acc: 0.523 Val acc: 0.457
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  11
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.936 Val loss: 1.028
# Train acc: 0.645 Val acc: 0.486
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  12
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.930 Val loss: 1.016
# Train acc: 0.701 Val acc: 0.543
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  13
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.926 Val loss: 1.006
# Train acc: 0.617 Val acc: 0.600
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  14
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.923 Val loss: 0.994
# Train acc: 0.645 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  15
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.920 Val loss: 0.987
# Train acc: 0.645 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  16
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.917 Val loss: 0.993
# Train acc: 0.617 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  17
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.915 Val loss: 0.989
# Train acc: 0.589 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  18
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.913 Val loss: 0.983
# Train acc: 0.636 Val acc: 0.600
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  19
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.909 Val loss: 0.981
# Train acc: 0.636 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  20
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.907 Val loss: 0.978
# Train acc: 0.617 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  21
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.904 Val loss: 0.976
# Train acc: 0.654 Val acc: 0.600
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  22
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.904 Val loss: 0.971
# Train acc: 0.607 Val acc: 0.600
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  23
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.900 Val loss: 0.967
# Train acc: 0.692 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  24
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.898 Val loss: 0.967
# Train acc: 0.636 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  25
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.895 Val loss: 0.964
# Train acc: 0.673 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  26
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.892 Val loss: 0.962
# Train acc: 0.636 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  27
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.889 Val loss: 0.958
# Train acc: 0.682 Val acc: 0.686
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  28
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.886 Val loss: 0.962
# Train acc: 0.710 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  29
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.883 Val loss: 0.960
# Train acc: 0.692 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  30
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.881 Val loss: 0.956
# Train acc: 0.673 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  31
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.878 Val loss: 0.954
# Train acc: 0.692 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  32
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.875 Val loss: 0.953
# Train acc: 0.654 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  33
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.873 Val loss: 0.948
# Train acc: 0.720 Val acc: 0.686
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  34
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.872 Val loss: 0.945
# Train acc: 0.701 Val acc: 0.686
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  35
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.868 Val loss: 0.944
# Train acc: 0.757 Val acc: 0.686
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  36
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.866 Val loss: 0.942
# Train acc: 0.720 Val acc: 0.686
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  37
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.866 Val loss: 0.949
# Train acc: 0.636 Val acc: 0.686
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  38
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.864 Val loss: 0.951
# Train acc: 0.738 Val acc: 0.686
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  39
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.861 Val loss: 0.949
# Train acc: 0.710 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  40
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.860 Val loss: 0.947
# Train acc: 0.701 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  41
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.858 Val loss: 0.945
# Train acc: 0.682 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  42
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.857 Val loss: 0.948
# Train acc: 0.692 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  43
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.855 Val loss: 0.947
# Train acc: 0.738 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  44
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.853 Val loss: 0.949
# Train acc: 0.738 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  45
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.851 Val loss: 0.947
# Train acc: 0.682 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  46
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.849 Val loss: 0.945
# Train acc: 0.701 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  47
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.846 Val loss: 0.943
# Train acc: 0.776 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  48
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.843 Val loss: 0.941
# Train acc: 0.757 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  49
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.841 Val loss: 0.940
# Train acc: 0.720 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  50
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.839 Val loss: 0.939
# Train acc: 0.729 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  51
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.837 Val loss: 0.937
# Train acc: 0.710 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  52
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.835 Val loss: 0.934
# Train acc: 0.738 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  53
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.833 Val loss: 0.932
# Train acc: 0.720 Val acc: 0.686
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  54
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.831 Val loss: 0.932
# Train acc: 0.729 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  55
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.830 Val loss: 0.930
# Train acc: 0.766 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  56
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.828 Val loss: 0.928
# Train acc: 0.692 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  57
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.826 Val loss: 0.926
# Train acc: 0.766 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  58
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.824 Val loss: 0.925
# Train acc: 0.729 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  59
# Adjusting learning rate of group 0 to 1.0000e-05.
# Train loss: 0.822 Val loss: 0.924
# Train acc: 0.748 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  60
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.820 Val loss: 0.924
# Train acc: 0.692 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  61
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.818 Val loss: 0.923
# Train acc: 0.729 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  62
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.817 Val loss: 0.922
# Train acc: 0.776 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  63
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.815 Val loss: 0.920
# Train acc: 0.738 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  64
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.813 Val loss: 0.919
# Train acc: 0.757 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  65
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.811 Val loss: 0.918
# Train acc: 0.701 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  66
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.810 Val loss: 0.917
# Train acc: 0.729 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  67
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.808 Val loss: 0.915
# Train acc: 0.692 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  68
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.807 Val loss: 0.914
# Train acc: 0.766 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  69
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.805 Val loss: 0.913
# Train acc: 0.748 Val acc: 0.686
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  70
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.804 Val loss: 0.912
# Train acc: 0.710 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  71
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.802 Val loss: 0.910
# Train acc: 0.776 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  72
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.801 Val loss: 0.909
# Train acc: 0.766 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  73
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.800 Val loss: 0.908
# Train acc: 0.720 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  74
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.799 Val loss: 0.908
# Train acc: 0.776 Val acc: 0.686
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  75
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.797 Val loss: 0.907
# Train acc: 0.738 Val acc: 0.686
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  76
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.796 Val loss: 0.906
# Train acc: 0.710 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  77
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.795 Val loss: 0.905
# Train acc: 0.729 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  78
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.794 Val loss: 0.904
# Train acc: 0.757 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  79
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.793 Val loss: 0.904
# Train acc: 0.748 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  80
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.792 Val loss: 0.904
# Train acc: 0.692 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  81
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.791 Val loss: 0.903
# Train acc: 0.785 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  82
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.790 Val loss: 0.902
# Train acc: 0.682 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  83
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.788 Val loss: 0.902
# Train acc: 0.804 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  84
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.787 Val loss: 0.900
# Train acc: 0.738 Val acc: 0.686
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  85
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.786 Val loss: 0.900
# Train acc: 0.738 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  86
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.785 Val loss: 0.899
# Train acc: 0.776 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  87
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.783 Val loss: 0.898
# Train acc: 0.729 Val acc: 0.686
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  88
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.782 Val loss: 0.898
# Train acc: 0.822 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  89
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.781 Val loss: 0.899
# Train acc: 0.748 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  90
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.780 Val loss: 0.901
# Train acc: 0.766 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  91
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.780 Val loss: 0.900
# Train acc: 0.664 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  92
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.779 Val loss: 0.901
# Train acc: 0.776 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  93
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.778 Val loss: 0.899
# Train acc: 0.710 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  94
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.777 Val loss: 0.900
# Train acc: 0.776 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  95
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.776 Val loss: 0.899
# Train acc: 0.720 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  96
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.775 Val loss: 0.898
# Train acc: 0.757 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  97
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.774 Val loss: 0.898
# Train acc: 0.766 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  98
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.774 Val loss: 0.897
# Train acc: 0.720 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  99
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.773 Val loss: 0.896
# Train acc: 0.785 Val acc: 0.686
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  100
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.772 Val loss: 0.896
# Train acc: 0.729 Val acc: 0.686
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  101
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.772 Val loss: 0.898
# Train acc: 0.757 Val acc: 0.686
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  102
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.771 Val loss: 0.898
# Train acc: 0.748 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  103
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.770 Val loss: 0.897
# Train acc: 0.785 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  104
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.770 Val loss: 0.896
# Train acc: 0.729 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  105
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.769 Val loss: 0.895
# Train acc: 0.720 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  106
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.768 Val loss: 0.894
# Train acc: 0.766 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  107
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.767 Val loss: 0.894
# Train acc: 0.757 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  108
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.767 Val loss: 0.894
# Train acc: 0.729 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  109
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.766 Val loss: 0.894
# Train acc: 0.757 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  110
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.766 Val loss: 0.894
# Train acc: 0.766 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  111
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.765 Val loss: 0.894
# Train acc: 0.766 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  112
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.764 Val loss: 0.895
# Train acc: 0.692 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  113
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.764 Val loss: 0.895
# Train acc: 0.757 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  114
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.764 Val loss: 0.896
# Train acc: 0.738 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  115
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.763 Val loss: 0.897
# Train acc: 0.785 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  116
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.762 Val loss: 0.897
# Train acc: 0.785 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  117
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.762 Val loss: 0.895
# Train acc: 0.794 Val acc: 0.629
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  118
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.761 Val loss: 0.895
# Train acc: 0.748 Val acc: 0.657
# --------------------------------------------------------------------------------------------------------------------
# Epoch :  119
# Adjusting learning rate of group 0 to 1.0000e-06.
# Train loss: 0.760 Val loss: 0.894
# Train acc: 0.776 Val acc: 0.686
# --------------------------------------------------------------------------------------------------------------------
# Early stopping

# %%
draw_training_curves(losses['train'],losses['val'], 'Phq_loss', 13 )
#PHQ 256 works best for hidden layer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-800414c8bd3d> in <module>()
# ----> 1 draw_training_curves(losses['train'],losses['val'], 'Phq_loss', 13 )
#       2 #PHQ 256 works best for hidden layer
#
# NameError: name 'draw_training_curves' is not defined

# %%
draw_training_curves(accuracy['train'],accuracy['val'], 'Phq_acc', 13 )

# %%
def evaluate_single_task(task, model, test_loader):
  output = []
  actual = []
  model.eval()
  with torch.no_grad():
    for sentence, length, phq_score, ptsd_score in test_loader:
      sentence = sentence.to(DEVICE).long()
      phq_score = phq_score.to(DEVICE).type(torch.float32)
      ptsd_score = ptsd_score.to(DEVICE).type(torch.float32)
      if task == 'PHQ':
        label = phq_score
      else: 
        label = ptsd_score
      
      phqop,ptsdop = model(sentence, length)

      output.extend(phqop.cpu().tolist())
      actual.extend(phq_score.cpu().tolist())

  return actual, output

test_loader = torch.utils.data.DataLoader(DepressionDataset(test_encoded, test_PHQ, test_PTSD), batch_size=batch_size, shuffle=False)
actual, preds = evaluate_single_task("PHQ", model, test_loader)

final_actual = []
final_pred = []

for val in actual:
  if val < 5:
    final_actual.append("None")
  elif val > 4 and val<15:
    final_actual.append("Mild to moderate")
  else:
    final_actual.append("Severe")

for val in preds:
  if val < 5:
    final_pred.append("None")
  elif val > 4 and val<15:
    final_pred.append("Mild to moderate")
  else:
    final_pred.append("Severe")

correct = 0
total = 0
for x,y in zip(final_actual, final_pred):
  if x == y:
    correct+=1
  total+=1

print("Accuracy: ", correct/total)
# Out:
# Accuracy:  0.425531914893617

# %%
"""
References:
1. https://docs.google.com/document/d/1_PycTNBTQjboYtyZslkte0WlcdyMlyFTMYZlSHLq0EE/edit#
"""
